# %% [markdown]
# # NLP COVID Vax Data

# %%
import pandas as pd
import numpy as np

pd.set_option("max_colwidth", 0)
pd.set_option('max_columns', 35)
np.set_printoptions(suppress=True) # Suppress scientific notation where possible

# %% [markdown]
# ## Import & combine tweetIDs
# Tweet IDs come from this dataset: https://github.com/gmuric/avax-tweets-dataset and were obtained by searching twitter for anti-COVID-19 vaccine-related hashtags between October 2020 and April 2021

# %%
def combine_tweetIDs(year_month, days_in_month):
    ''' Imports text files containing tweetIDs and combines a month-worth of 
    tweetIDs into a single df
    '''
    tweet_list = []
    for day in range(1, days_in_month + 1):
        if day < 10:
            day = '0' + str(day)
        else:
            day = str(day)
        for hour in range(0,24):
            if hour < 10:
                hour = '0' + str(hour)
            else:
                hour = str(hour)
            try:
                link = ('avax-tweets-dataset/streaming-tweetids/' 
                            + year_month + '/'
                           + year_month + '-'
                            + day + '-'
                            +hour +'.txt'
                               )
                new_tweets = pd.read_csv(link, header=None)
                tweet_list.append(new_tweets)  
            except FileNotFoundError:
                print('File not found')
    return pd.concat(tweet_list, ignore_index=True)

# %% [markdown]
# ### Collecting 1 month of tweetIDs & exporting to Hydrator app

# %% [markdown]
# #### November 2020

# %%
# November 2020

tweetIDs_2020_11 = combine_tweetIDs(year_month='2020-11', days_in_month=30)
tweetIDs_2020_11.columns = ['TweetID']
tweetIDs_2020_11.head(3)
# Out:
#                TweetID
# 0  1322795488928673792
# 1  1322795535565156353
# 2  1322795640275968000

# %%
tweetIDs_2020_11.shape
# Out:
# (202897, 1)

# %%
# exporting November 2020 tweetIDs

tweetIDs_2020_11.to_csv('my_twitter_data/tweetIDs_2020_11.csv', header=False, index=False)

# %% [markdown]
# #### December 2020

# %%
# December 2020

tweetIDs_2020_12 = combine_tweetIDs(year_month='2020-12', days_in_month=31)
tweetIDs_2020_12.columns = ['TweetID']
tweetIDs_2020_12.head(3)
# Out:
#                TweetID
# 0  1333682291101605889
# 1  1333682356675354624
# 2  1333682389634207744

# %%
tweetIDs_2020_12.shape
# Out:
# (269915, 1)

# %%
# two rows say 'tweetid' instead of an id number

tweetIDs_2020_12[tweetIDs_2020_12['TweetID'] == 'tweetid']
# Out:
#         TweetID
# 209554  tweetid
# 236997  tweetid

# %%
# dropping the 'tweetid' rows

tweetIDs_2020_12 = tweetIDs_2020_12.drop([209554, 236997])

# %%
tweetIDs_2020_12.shape
# Out:
# (269913, 1)

# %%
# exporting December 2020 tweetIDs

tweetIDs_2020_12.to_csv('my_twitter_data/tweetIDs_2020_12.csv', header=False, index=False)

# %% [markdown]
# #### January 2021

# %%
# January 2021
# one file (17th at 15:00) was missing - so used try/except to skip it

tweetIDs_2021_01 = combine_tweetIDs(year_month='2021-01', days_in_month=31)
tweetIDs_2021_01.columns = ['TweetID']
tweetIDs_2021_01.head(3)
# Out:
# File not found
#                TweetID
# 0  1344916548725698561
# 1  1344916986120335360
# 2  1344917226009350144

# %%
tweetIDs_2021_01.shape
# Out:
# (179787, 1)

# %%
# exporting Jan 2021 tweetIDs

tweetIDs_2021_01.to_csv('my_twitter_data/tweetIDs_2021_01.csv', header=False, index=False)

# %% [markdown]
# #### February 2021

# %%
# February 2021

tweetIDs_2021_02 = combine_tweetIDs(year_month='2021-02', days_in_month=28)
tweetIDs_2021_02.columns = ['TweetID']
tweetIDs_2021_02.head(3)
# Out:
#                TweetID
# 0  1356150339355828226
# 1  1356150618692399105
# 2  1356150787580198916

# %%
tweetIDs_2021_02.shape
# Out:
# (202916, 1)

# %%
# exporting Feb 2021 tweetIDs

tweetIDs_2021_02.to_csv('my_twitter_data/tweetIDs_2021_02.csv', header=False, index=False)

# %% [markdown]
# #### March 2021

# %%
# March 2021
# one file not found

tweetIDs_2021_03 = combine_tweetIDs(year_month='2021-03', days_in_month=31)
tweetIDs_2021_03.columns = ['TweetID']
tweetIDs_2021_03.head(3)
# Out:
# File not found
#                TweetID
# 0  1366297418606776323
# 1  1366297481680723969
# 2  1366297498529202178

# %%
tweetIDs_2021_03.shape
# Out:
# (419432, 1)

# %%
# exporting March 2021 tweetIDs

tweetIDs_2021_03.to_csv('my_twitter_data/tweetIDs_2021_03.csv', header=False, index=False)

# %% [markdown]
# #### April 2021
# Through 4.20.21

# %%
# April 2021 - dataset ends after the 20th

tweetIDs_2021_04 = combine_tweetIDs(year_month='2021-04', days_in_month=20)
tweetIDs_2021_04.columns = ['TweetID']
tweetIDs_2021_04.head(3)
# Out:
#                TweetID
# 0  1377516074640539648
# 1  1377516103535095809
# 2  1377516134585532420

# %%
tweetIDs_2021_04.shape
# Out:
# (484372, 1)

# %%
# exporting April 2021 tweetIDs

tweetIDs_2021_04.to_csv('my_twitter_data/tweetIDs_2021_04.csv', header=False, index=False)

# %% [markdown]
# ## Combining hydrated Tweets
# Tweets have now been 'hydrated' by running through the Hydrator app: https://github.com/DocNow/hydrator

# %% [markdown]
# ### Importing and combining hydrated Tweets

# %% [markdown]
# Some definitions:
# >- Quote_id only surfaces when the Tweet is a quote Tweet. The field contains the Tweet ID of the quoted Tweet
# >- Re-tweet_count = number of times this Tweet has been retweeted

# %%
# Re-importing hydrated November 2020 data

hydrated_2020_11 = pd.read_csv('my_twitter_data/hydrated_2020_11.csv')
hydrated_2020_11.head()
# Out:
# /Users/mayaremington/opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   coordinates                      created_at hashtags media  \
# 0  NaN         Sun Nov 01 07:04:54 +0000 2020  NaN      NaN
# 1  NaN         Sun Nov 01 07:10:02 +0000 2020  NaN      NaN
# 2  NaN         Sun Nov 01 07:13:25 +0000 2020  NaN      NaN
# 3  NaN         Sun Nov 01 07:31:24 +0000 2020  NaN      NaN
# 4  NaN         Sun Nov 01 07:01:51 +0000 2020  NaN      NaN
#
#                                                        urls  favorite_count  \
# 0  https://twitter.com/LotusOak2/status/1322642287449591814  0
# 1  NaN                                                       0
# 2  NaN                                                       0
# 3  NaN                                                       0
# 4  NaN                                                       1
#
#                     id in_reply_to_screen_name  in_reply_to_status_id  \
# 0  1322796743298265088  NaN                    NaN
# 1  1322798033596272640  NaN                    NaN
# 2  1322798887694905346  NaN                    NaN
# 3  1322803412300431361  NaN                    NaN
# 4  1322795973337403395  bongzmessi              1.322170e+18
#
#    in_reply_to_user_id lang place possibly_sensitive      quote_id  \
# 0 NaN                   en   NaN   False              1.322642e+18
# 1 NaN                   en   NaN   NaN               NaN
# 2 NaN                   en   NaN   NaN               NaN
# 3 NaN                   en   NaN   NaN                1.322434e+18
# 4  217711495.0          en   NaN   NaN               NaN
#
#    retweet_count    retweet_id retweet_screen_name  \
# 0  0             NaN            NaN
# 1  489            1.322434e+18  sunnynwaobi1
# 2  122            1.322792e+18  conspiracyb0t
# 3  41             1.322774e+18  Onyinye51838197
# 4  0             NaN            NaN
#
#                                                                                  source  \
# 0  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 1  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 2  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#                                                                                                                                                                                                                                                                                                   text  \
# 0  Stay away from that vaccine. Population control. https://t.co/DTMFGsNRzX
# 1  Isn't this a systematic depopulation happing in Obigbo?, where young unarmed citizens are randomly picked, some tortured while some are killed. #Obigbomassacre @StateDept @AmnestyNigeria @ https://t.co/TsakU0l3Fm
# 2  Bill Gates is one of the biggest proponents of mass depopulation.
# 3  The world should be on notice that Nelson nwike river state governor and the Nigeria army are committing genocide and pogrom in Biafra land https://t.co/fTC8gNNSsZ
# 4  @bongzmessi To come to think of it perhaps this was done so they multiply and outnumber us but. To them the depopulation agenda is at top of their list. Phela my King bake baphahluke labantu telling things they were not supposed like the one on an interview that they injected AIDS to blacks
#
#                                                         tweet_url  \
# 0  https://twitter.com/BAChatwin/status/1322796743298265088
# 1  https://twitter.com/jumoke_ladan/status/1322798033596272640
# 2  https://twitter.com/wambo161/status/1322798887694905346
# 3  https://twitter.com/EmmanuelNwanyim/status/1322803412300431361
# 4  https://twitter.com/Boniswa63207956/status/1322795973337403395
#
#                   user_created_at              user_id  \
# 0  Mon Sep 19 17:13:57 +0000 2011  376304718
# 1  Wed Jul 01 19:30:15 +0000 2009  52824297
# 2  Fri Apr 08 16:05:41 +0000 2011  279106686
# 3  Tue Apr 21 07:16:59 +0000 2020  1252496422865375238
# 4  Mon May 25 12:43:06 +0000 2020  1264899714950062080
#
#    user_default_profile_image  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                                                                                                           user_description  \
# 0  ☀️🇨🇦🌍Truth☀️🇨🇦🌍 Freedom ☀️🇨🇦🌏Health ☀️🇨🇦🌍Eyes wide open\nAwake patriot and CF veteran (13+yrs)
# 1  Am a Christian by God's grace. Called by Christ to serve and love Him as a Catholic. Perpetually loving Him.
# 2  Follower of Jesus.
# 3  i was born to shine take it or live it...blessed son by God in heaven..🙌🏼🙌🏼🙌🏼..peace 👍🏻 ...Biafran citizen Israel 🇮🇱 citizen
# 4  Mayibuye iAfrika✊🏾. \n\nI don't call my people Kings and Queens to tickle my throat it's because we are Royalty 👸🏾🤴🏿.\nTribalism 🤮Feminism 🤮Xenophobia🤮
#
#    user_favourites_count  user_followers_count  user_friends_count  \
# 0  1643                   130                   658
# 1  7009                   224                   359
# 2  27413                  205                   711
# 3  8947                   121                   307
# 4  39392                  3658                  3680
#
#    user_listed_count         user_location              user_name  \
# 0  0                  Niagara, Ontario      Barb Chatwin
# 1  1                  Lagos, Nigeria        Olajumoke Ladan
# 2  3                   la montaña de roble  James of Oak Mountain
# 3  1                  Israel                Emmanuel nwanyim
# 4  2                  NaN                   Boniswa
#
#   user_screen_name  user_statuses_count  user_time_zone user_urls  \
# 0  BAChatwin        2659                NaN              NaN
# 1  jumoke_ladan     1812                NaN              NaN
# 2  wambo161         48229               NaN              NaN
# 3  EmmanuelNwanyim  16345               NaN              NaN
# 4  Boniswa63207956  40107               NaN              NaN
#
#    user_verified
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
hydrated_2020_11.shape
# Out:
# (40764, 35)

# %%
# Re-importing hydrated December 2020 data

hydrated_2020_12 = pd.read_csv('my_twitter_data/hydrated_2020_12.csv')
hydrated_2020_12.head()
# Out:
# /Users/mayaremington/opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   coordinates                      created_at  \
# 0  NaN         Tue Dec 01 08:23:18 +0000 2020
# 1  NaN         Tue Dec 01 08:30:21 +0000 2020
# 2  NaN         Tue Dec 01 08:16:39 +0000 2020
# 3  NaN         Tue Dec 01 08:10:48 +0000 2020
# 4  NaN         Tue Dec 01 08:01:33 +0000 2020
#
#                                                              hashtags media  \
# 0  NoVaccineForMe                                                      NaN
# 1  NaN                                                                 NaN
# 2  NaN                                                                 NaN
# 3  michaelgove BorisJohnson matthancock scamdemic covid forcedvaccine  NaN
# 4  NaN                                                                 NaN
#
#                                                                                                        urls  \
# 0  https://www.facebook.com/MrWillFairfield/videos/384251992885450/
# 1  NaN
# 2  NaN
# 3  https://www.mirror.co.uk/news/politics/michael-gove-says-covid-19-23095692.amp?__twitter_impression=true
# 4  NaN
#
#    favorite_count                   id in_reply_to_screen_name  \
# 0  0               1333688107556872193  NaN
# 1  2               1333689884280844289  noma4freedom
# 2  0               1333686436164366336  NaN
# 3  0               1333684963250741249  NaN
# 4  14              1333682634640265216  NaN
#
#    in_reply_to_status_id  in_reply_to_user_id lang place possibly_sensitive  \
# 0 NaN                    NaN                   und  NaN   False
# 1  1.333688e+18           8.628060e+17         en   NaN   NaN
# 2 NaN                    NaN                   en   NaN   NaN
# 3 NaN                    NaN                   en   NaN   False
# 4 NaN                    NaN                   en   NaN   NaN
#
#        quote_id  retweet_count    retweet_id retweet_screen_name  \
# 0 NaN            0             NaN            NaN
# 1 NaN            0             NaN            NaN
# 2  1.333624e+18  1              1.333629e+18  violetblue
# 3 NaN            0             NaN            NaN
# 4 NaN            1             NaN            NaN
#
#                                                                                     source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="https://tapbots.com/software/tweetbot/mac" rel="nofollow">Tweetbot for Mac</a>
# 3  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 4  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
#
#                                                                                                                                                                                                                                                                         text  \
# 0  https://t.co/3qrtBnDF8v? #NoVaccineForMe
# 1  @patrioticnomes @LBC @NickFerrariLBC Not that long ago people predicting this were called conspiracy theorists hey but according to some polls it appears 50% of the public want mandated vaccines or at least for non vaxxed to be refused entry to places 🙄😔 sad times.
# 2  "nearly 90,000 households have relocated outside of the city" &lt; in the past six months... aka why the houses around me are dark and quiet now. https://t.co/dONbAaQaPI
# 3  If #michaelgove #BorisJohnson and #matthancock say it will not happen, then its 100% guaranteed that it will. https://t.co/yaD4nfOv3f\n#scamdemic #covid #forcedvaccine
# 4  @Jon_statistics It's all part of the depopulation planning.
#
#                                                        tweet_url  \
# 0  https://twitter.com/Davis1973Sarah/status/1333688107556872193
# 1  https://twitter.com/gareth78t/status/1333689884280844289
# 2  https://twitter.com/mars_seven/status/1333686436164366336
# 3  https://twitter.com/nicktweetuk/status/1333684963250741249
# 4  https://twitter.com/YrHenGwrcyn/status/1333682634640265216
#
#                   user_created_at             user_id  \
# 0  Tue Nov 04 09:34:38 +0000 2014  2860208369
# 1  Fri Jul 11 09:24:47 +0000 2014  2698364615
# 2  Sat Dec 27 01:49:16 +0000 2008  18399799
# 3  Mon Feb 20 10:16:05 +0000 2017  833621238039924736
# 4  Tue Nov 15 02:33:55 +0000 2011  412735280
#
#    user_default_profile_image  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                                                                           user_description  \
# 0  mother ... wife ... animal lover ... music lover ... getting Fit not lit ... trusting my immune system Enough is Enough
# 1  I like a certain amount of privacy therefore I choose not to say too much about myself on the interweb!
# 2  Huh? What? Never mind.
# 3  NaN
# 4  Views and opinions my own, retweet ≠ endorsement.\nnow on GAB - @bladerider
#
#    user_favourites_count  user_followers_count  user_friends_count  \
# 0  12951                  832                   2173
# 1  3151                   118                   382
# 2  1257                   276                   609
# 3  7568                   52                    101
# 4  135290                 1011                  481
#
#    user_listed_count              user_location  \
# 0  4                  NaN
# 1  1                  wherever I am at the time
# 2  74                 San Francisco
# 3  0                  NaN
# 4  2                  Stalag-15
#
#                                       user_name user_screen_name  \
# 0  Sarah Davis                                   Davis1973Sarah
# 1  GT                                            gareth78t
# 2  mars_seven                                    mars_seven
# 3  Nick                                          nicktweetuk
# 4  Bladerider - "Everything WOKE turns to shit"  YrHenGwrcyn
#
#    user_statuses_count  user_time_zone                   user_urls  \
# 0  4847                NaN              NaN
# 1  2260                NaN              NaN
# 2  74839               NaN              http://www.mars-seven.com/
# 3  7742                NaN              NaN
# 4  45786               NaN              NaN
#
#    user_verified
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
hydrated_2020_12.shape
# Out:
# (84058, 35)

# %%
# Re-importing hydrated January 2021 data

hydrated_2021_01 = pd.read_csv('my_twitter_data/hydrated_2021_01.csv')
hydrated_2021_01.head()
# Out:
# /Users/mayaremington/opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   coordinates                      created_at  \
# 0  NaN         Fri Jan 01 08:22:10 +0000 2021
# 1  NaN         Fri Jan 01 08:16:08 +0000 2021
# 2  NaN         Fri Jan 01 08:52:29 +0000 2021
# 3  NaN         Fri Jan 01 08:42:33 +0000 2021
# 4  NaN         Fri Jan 01 08:12:16 +0000 2021
#
#                                                     hashtags media  \
# 0  informedconsent toryliars resignHancock genow pfizer mhra  NaN
# 1  NaN                                                        NaN
# 2  Left ChinaVirus Vaccine                                    NaN
# 3  NaN                                                        NaN
# 4  NoMasks NoVaccines                                         NaN
#
#                                                      urls  favorite_count  \
# 0  NaN                                                     0
# 1  NaN                                                     1
# 2  NaN                                                     0
# 3  NaN                                                     1
# 4  https://twitter.com/CBSNews/status/1344911164740874241  0
#
#                     id in_reply_to_screen_name  in_reply_to_status_id  \
# 0  1344921847587074048  itsBenRandell           1.344920e+18
# 1  1344920328586350592  NaN                    NaN
# 2  1344929478087159810  NaN                    NaN
# 3  1344926977891954688  joesnoboard             1.344910e+18
# 4  1344919354526191616  NaN                    NaN
#
#    in_reply_to_user_id lang place possibly_sensitive      quote_id  \
# 0  50371532.0           en   NaN   NaN               NaN
# 1 NaN                   en   NaN   NaN               NaN
# 2 NaN                   en   NaN   NaN                1.344795e+18
# 3  94901637.0           en   NaN   NaN               NaN
# 4 NaN                   en   NaN   False              1.344911e+18
#
#    retweet_count    retweet_id retweet_screen_name  \
# 0  0             NaN            NaN
# 1  0             NaN            NaN
# 2  2              1.344928e+18  votenickmoutos
# 3  1             NaN            NaN
# 4  0             NaN            NaN
#
#                                                                                  source  \
# 0  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 3  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 4  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
#
#                                                                                                                                                                                                                                                                                text  \
# 0  @itsBenRandell Believe this is actually illegal for those already had 1st dose. No #informedconsent #toryliars #resignHancock #genow #pfizer #mhra
# 1  @syghe @empalattella @LLinWood @HelenKennedy Libs LOVE masks bc now they can go out in public w/o feeling self-conscious and ashamed by their appearance, while also fueling their relentlessly thirsty EGO by virtue shaming others. Lol Can’t wait for them all to get vaxxed.
# 2  I’m all for the mask muppets of the #Left getting the #ChinaVirus #Vaccine. Whether it sterilizes them, is toxic, I don’t care. #NoVaccineForMe Let them vaccinate themselves out of existence! https://t.co/SzZSrCEgrl
# 3  @joesnoboard @MduBrianC1 @Lungah__ Now, with you intellectual superiority, do you ever think that Gates or any leader would openly admit their commitment to depopulation?\nThe newspaper in question has not redacted their article nor apologised to Gates.
# 4  He is a hero! Vaccines will kill us all! #NoMasks! #NoVaccines! https://t.co/hGaqSvA3nu
#
#                                                         tweet_url  \
# 0  https://twitter.com/iamnothelch/status/1344921847587074048
# 1  https://twitter.com/realriasprague1/status/1344920328586350592
# 2  https://twitter.com/Maria95321214/status/1344929478087159810
# 3  https://twitter.com/onderrok/status/1344926977891954688
# 4  https://twitter.com/riker17/status/1344919354526191616
#
#                   user_created_at              user_id  \
# 0  Thu Dec 24 20:26:42 +0000 2020  1342205037179789319
# 1  Wed Dec 30 12:06:09 +0000 2020  1344253388742160384
# 2  Tue May 19 17:16:38 +0000 2020  1262794215723057153
# 3  Thu Aug 07 14:48:52 +0000 2014  2736252034
# 4  Wed Jan 02 20:30:51 +0000 2008  11770332
#
#    user_default_profile_image  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                                                                                                                    user_description  \
# 0  "subsistence level twitterage"\nYou got Brexit done. Now fuck off.\nMember of both #monoCulture and #CultOfSelfish Resistance movements.\n#FBPA #FBPE #FBPPR
# 1  Trump 2020. American 🇺🇸 Patriot. Constantly banned from this $hit platform. Ready to fight back like it’s 1776. @LLinwood is the reason I’m back.
# 2  🚀🌿IT'S HARD TO GIVE UNLIMITED POWER TO LIMITED MIND.🌿🚀TRUMP♥️Q♥️JFKjr ♥️🌿🚀
# 3  Tech entrepreneur, coin collector, social commentator. In that order!
# 4  My opinions are real and blunt. I take no guff. Political Correctness is wrong! Proud No Agenda Knight. #Freedom #AmericaFirst @twrsradio ITM! #NoVaccines ever!
#
#    user_favourites_count  user_followers_count  user_friends_count  \
# 0  13650                  1771                  2415
# 1  107                    5                     14
# 2  24079                  223                   859
# 3  1916                   142                   265
# 4  97971                  1025                  4998
#
#    user_listed_count       user_location  \
# 0  1                  NaN
# 1  0                  United States
# 2  0                  Roma, IT🚀Prague,CZ
# 3  2                  The Toilet
# 4  50                 Dos Palos, CA
#
#                                             user_name user_screen_name  \
# 0  iamnothelch 💙 #FBPPR #FBNHS #JohnsonOut             iamnothelch
# 1  Maria Sprague                                       realriasprague1
# 2  🍀MARIA🍀                                             Maria95321214
# 3  Anon Cognito                                        onderrok
# 4  COVID #hoax survivor Will James Robertson #NoMasks  riker17
#
#    user_statuses_count  user_time_zone                user_urls  user_verified
# 0  17130               NaN              NaN                      False
# 1  70                  NaN              NaN                      False
# 2  11672               NaN              NaN                      False
# 3  5352                NaN              Https://Kidztours.co.za  False
# 4  43721               NaN              https://www.riker17.com  False

# %%
hydrated_2021_01.shape
# Out:
# (122966, 35)

# %%
# Re-importing hydrated February 2021 data

hydrated_2021_02 = pd.read_csv('my_twitter_data/hydrated_2021_02.csv')
hydrated_2021_02.head()
# Out:
# /Users/mayaremington/opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   coordinates                      created_at      hashtags media  \
# 0  NaN         Mon Feb 01 08:32:58 +0000 2021  NaN           NaN
# 1  NaN         Mon Feb 01 08:09:21 +0000 2021  NaN           NaN
# 2  NaN         Mon Feb 01 08:03:36 +0000 2021  depopulation  NaN
# 3  NaN         Mon Feb 01 08:41:44 +0000 2021  NaN           NaN
# 4  NaN         Mon Feb 01 08:51:16 +0000 2021  NaN           NaN
#
#                                                           urls  \
# 0  NaN
# 1  NaN
# 2  https://twitter.com/jamesperloff/status/1355363087155687425
# 3  NaN
# 4  https://twitter.com/abuttenheim/status/1355587111974547462
#
#    favorite_count                   id in_reply_to_screen_name  \
# 0  4               1356158588687941632  86Cujo
# 1  0               1356152644813905923  vonderleyen
# 2  0               1356151200731836419  NaN
# 3  0               1356160793348354050  SteveG06322664
# 4  0               1356163194285416448  LucaFerrettiEvo
#
#    in_reply_to_status_id  in_reply_to_user_id lang place possibly_sensitive  \
# 0  1.356158e+18           4.534015e+08         en   NaN   NaN
# 1  1.355942e+18           1.146330e+18         en   NaN   NaN
# 2 NaN                    NaN                   en   NaN   False
# 3  1.355939e+18           1.248268e+18         en   NaN   NaN
# 4 NaN                     1.032006e+18         und  NaN   False
#
#        quote_id  retweet_count    retweet_id retweet_screen_name  \
# 0 NaN            1             NaN            NaN
# 1 NaN            0             NaN            NaN
# 2  1.355363e+18  1              1.355457e+18  DrBroncanuus
# 3 NaN            0             NaN            NaN
# 4  1.355587e+18  0             NaN            NaN
#
#                                                                                  source  \
# 0  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 3  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#                                                                                                                                                                                                                                                             text  \
# 0  @86Cujo @vsuperstar1 @CarlHen10428180 No such thing as global warming Gates is only blocking the sun so we get a lack in Vitiman D just one of a handful of his ideas to help with his depopulation plan.
# 1  @vonderleyen @AstraZeneca Erm... but that WAS last week’s offer wasn’t it? And you wanted 120m doses, right? Why are you presenting 39m doses as (a) news and (b) a good thing? How many EU citizens does that leave unvaccinated and vulnerable?
# 2  #depopulation has begun https://t.co/KxIbXV7uTa
# 3  @SteveG06322664 @afneil My brother just died from c-19. He'd been fine 3 weeks ago. His wife has health issues - has tested positive, is asymptomatic, neither had the vaccine but an unvaccinated carer calls every day. I wonder how they got the virus! 🥺😡
# 4  @LucaFerrettiEvo https://t.co/VRafR8ruHT
#
#                                                       tweet_url  \
# 0  https://twitter.com/sdaws5MUFC/status/1356158588687941632
# 1  https://twitter.com/SussexBoil/status/1356152644813905923
# 2  https://twitter.com/ValerieCurren/status/1356151200731836419
# 3  https://twitter.com/WinnieAtwell/status/1356160793348354050
# 4  https://twitter.com/alice_ledda_/status/1356163194285416448
#
#                   user_created_at              user_id  \
# 0  Mon Jan 24 18:45:44 +0000 2011  242414603
# 1  Tue Aug 09 22:11:38 +0000 2011  351914246
# 2  Wed May 16 07:28:35 +0000 2012  581613862
# 3  Sat Dec 29 13:58:36 +0000 2018  1079013820960514049
# 4  Tue Aug 21 20:28:27 +0000 2018  1032001505157689344
#
#    user_default_profile_image  \
# 0  False
# 1  False
# 2  True
# 3  False
# 4  False
#
#                                                                                                    user_description  \
# 0  Earth is Flat 👁 #420
# 1  He who stifles free discussion secretly doubts whether what he professes to believe is really true ~ W. Phillips
# 2  NaN
# 3  NaN
# 4  Evolutionary Scientist, Very Curious Person, Old School Social.
#
#    user_favourites_count  user_followers_count  user_friends_count  \
# 0  14931                  11880                 3159
# 1  28291                  722                   1944
# 2  39535                  1248                  4837
# 3  644                    10                    31
# 4  60695                  1320                  791
#
#    user_listed_count   user_location          user_name user_screen_name  \
# 0  89                 Frinton         Steve              sdaws5MUFC
# 1  2                  United Kingdom  Amieas             SussexBoil
# 2  2                  NaN             Valerie Curren     ValerieCurren
# 3  0                  NaN             EBBOM              WinnieAtwell
# 4  13                 Europe          AliceLedda, PhD 💙  alice_ledda_
#
#    user_statuses_count  user_time_zone user_urls  user_verified
# 0  28830               NaN              NaN       False
# 1  13911               NaN              NaN       False
# 2  71828               NaN              NaN       False
# 3  873                 NaN              NaN       False
# 4  11235               NaN              NaN       False

# %%
hydrated_2021_02.shape
# Out:
# (144145, 35)

# %%
# Re-importing hydrated March 2021 data

hydrated_2021_03 = pd.read_csv('my_twitter_data/hydrated_2021_03.csv')
hydrated_2021_03.head()
# Out:
# /Users/mayaremington/opt/anaconda3/envs/metis/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   coordinates                      created_at        hashtags media  \
# 0  NaN         Mon Mar 01 08:24:19 +0000 2021  NaN             NaN
# 1  NaN         Mon Mar 01 08:23:00 +0000 2021  NoVaccineForMe  NaN
# 2  NaN         Mon Mar 01 08:33:56 +0000 2021  NaN             NaN
# 3  NaN         Mon Mar 01 08:18:30 +0000 2021  NaN             NaN
# 4  NaN         Mon Mar 01 08:13:06 +0000 2021  NaN             NaN
#
#                                                       urls  favorite_count  \
# 0  https://mol.im/a/9310829                                 8
# 1  https://twitter.com/NakkachM/status/1366120607604211712  3
# 2  NaN                                                      3
# 3  NaN                                                      0
# 4  NaN                                                      0
#
#                     id in_reply_to_screen_name  in_reply_to_status_id  \
# 0  1366303272345219073  NaN                    NaN
# 1  1366302942417027075  NaN                    NaN
# 2  1366305691313520643  MissDemeanor___         1.366301e+18
# 3  1366301809405485060  NaN                    NaN
# 4  1366300449880612864  NaN                    NaN
#
#    in_reply_to_user_id lang place possibly_sensitive      quote_id  \
# 0 NaN                   en   NaN   False             NaN
# 1 NaN                   en   NaN   False              1.366121e+18
# 2  1.362055e+18         en   NaN   NaN               NaN
# 3 NaN                   en   NaN   NaN               NaN
# 4 NaN                   en   NaN   NaN                1.361286e+18
#
#    retweet_count    retweet_id retweet_screen_name  \
# 0  1             NaN            NaN
# 1  0             NaN            NaN
# 2  0             NaN            NaN
# 3  16             1.366299e+18  AbdullahHasib2
# 4  8              1.366176e+18  JumboJones56
#
#                                                                                  source  \
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 2  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 3  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#                                                                                                                                                                                                                                                                                                                                 text  \
# 0  Unvaccinated officers 'DO NOT want to continue policing Covid rules'\nIf They Have Stayed In Same County No Problem! But Police Could Establish That From Number Plate! https://t.co/I7dciZrbEl
# 1  If beleiving in the opposite  truth makes me a conspiracy theorist...then be it....i prefer that to being called a blind follower....#NoVaccineForMe https://t.co/wiU5kp74SE
# 2  @Rebel__Teacher @LBC @NickFerrariLBC Because the virus would continue to spread around the unvaccinated, possibly with less casualties, but with each new host chances of new mutations, creating new variants increases. These may be both more deadly &amp; impervious to the current vaccines. Even to athletes like yourself.
# 3  @piersmorgan \nWhy do you keep describing the lockdown roadmap as 'sensible' when 10 million children and 500,000 mostly unvaccinated teachers are going to be forced back into the often poorly ventilated confines of a classroom come next week? Obvious infection rates will rocket!
# 4  @AlexFerguson50 @thearmouryblog @battleaxeBrit1 Max didn’t say that they were mandatory.\n\nHe is talking about stuff like this 👇 https://t.co/c7DqOwFGPb
#
#                                                         tweet_url  \
# 0  https://twitter.com/boblister_poole/status/1366303272345219073
# 1  https://twitter.com/meia_j_hk/status/1366302942417027075
# 2  https://twitter.com/LiberiaGod/status/1366305691313520643
# 3  https://twitter.com/eveningperson/status/1366301809405485060
# 4  https://twitter.com/IreneBu62640342/status/1366300449880612864
#
#                   user_created_at              user_id  \
# 0  Mon Oct 20 17:41:55 +0000 2014  2838333676
# 1  Sun Oct 20 11:07:05 +0000 2019  1185875016237441024
# 2  Sat Feb 22 07:54:57 +0000 2020  1231125163229487104
# 3  Thu May 21 11:44:36 +0000 2009  41570929
# 4  Tue Nov 17 19:02:13 +0000 2020  1328775348557910016
#
#    user_default_profile_image  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                                                                                                               user_description  \
# 0  Why Haven’t We Stopped Flights From Most Countries Into The UK? Boris Must Get Tough With Cabinet Clearout, Support UK Fishing, Stop Illegal Migrant Boats!
# 1  ceci n'est pas un vide.....\n\nhttps://t.co/wVUZoOMXLq
# 2  Liberians for Trump 2020... kinda...\n\n#MLGA
# 3  Picture valid as ever. Wear a mask.  🏳️‍🌈 💖💜💙 RTs only for interest. Trolls blocked. If you can't sustain reasoned argument, you're muted. Voted in 1975.
# 4  I don't vote Snp and never will I voted to leave the EU #TakeOffYourMask🌸🌸🌸
#
#    user_favourites_count  user_followers_count  user_friends_count  \
# 0  125488                 39772                 25696
# 1  35729                  2457                  2016
# 2  69                     12                    20
# 3  3142                   3408                  4881
# 4  280933                 4080                  3272
#
#    user_listed_count             user_location              user_name  \
# 0  140                South West, England       Bob For A Full Brexit
# 1  1                  NaN                       مَيَّا
# 2  0                  NaN                       GodBlessLiberians
# 3  12                 Shrewsbury & Bristol      Richard Burnham
# 4  4                  Scotland, United Kingdom  Irene 🌸
#
#   user_screen_name  user_statuses_count  user_time_zone  \
# 0  boblister_poole  261395              NaN
# 1  meia_j_hk        8488                NaN
# 2  LiberiaGod       629                 NaN
# 3  eveningperson    65105               NaN
# 4  IreneBu62640342  87900               NaN
#
#                              user_urls  user_verified
# 0  NaN                                  False
# 1  NaN                                  False
# 2  NaN                                  False
# 3  https://eveningperson.wordpress.com  False
# 4  NaN                                  False

# %%
hydrated_2021_03.shape
# Out:
# (321807, 35)

# %%
# Re-importing hydrated April 2021 data

hydrated_2021_04 = pd.read_csv('my_twitter_data/hydrated_2021_04.csv')
hydrated_2021_04.head()
# Out:
#   coordinates                      created_at hashtags media  \
# 0  NaN         Thu Apr 01 07:04:45 +0000 2021  NaN      NaN
# 1  NaN         Thu Apr 01 07:06:33 +0000 2021  NaN      NaN
# 2  NaN         Thu Apr 01 07:18:35 +0000 2021  NaN      NaN
# 3  NaN         Thu Apr 01 07:07:10 +0000 2021  NaN      NaN
# 4  NaN         Thu Apr 01 07:19:07 +0000 2021  NaN      NaN
#
#                                                                                                                                                                                                                                                                            urls  \
# 0  https://twitter.com/Flobga/status/1377346654827802627
# 1  NaN
# 2  NaN
# 3  https://www.lifesitenews.com/opinion/wristbands-and-dining-cards-new-army-policies-exclude-isolate-unvaccinated?utm_source=LifeSiteNews.com&utm_campaign=c76a269c7d-Daily%2520Headlines%2520-%2520World_COPY_987&utm_medium=email&utm_term=0_12387f0e3e-c76a269c7d-406664550
# 4  NaN
#
#    favorite_count                   id in_reply_to_screen_name  \
# 0  0               1377517270667255810  NaN
# 1  0               1377517723798888448  NaN
# 2  1               1377520752006664192  Carolramsden6
# 3  0               1377517881601224704  NaN
# 4  0               1377520887247814656  NaN
#
#    in_reply_to_status_id  in_reply_to_user_id lang place possibly_sensitive  \
# 0 NaN                    NaN                   fr   NaN   False
# 1 NaN                    NaN                   en   NaN   NaN
# 2  1.377320e+18           1.369255e+18         en   NaN   NaN
# 3 NaN                    NaN                   und  NaN   False
# 4 NaN                    NaN                   en   NaN   NaN
#
#        quote_id  retweet_count    retweet_id retweet_screen_name  \
# 0  1.377347e+18  40             1.377377e+18  GladysPotiron
# 1 NaN            1255           1.376814e+18  CrimsonCode1
# 2 NaN            0             NaN            NaN
# 3 NaN            1             NaN            NaN
# 4 NaN            2323           1.377417e+18  EricMMatheny
#
#                                                                                  source  \
# 0  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 1  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#                                                                                                                                                                                                                                                                               text  \
# 0  Pendant que Macron monopolise les français, cette MONSTRUEUSE déclaration passe inaperçue 😡👎😡😭 https://t.co/XbAcCD0PC3
# 1  Everyone; Vaxxed or Unvaxxed whatever your choice, should reject any form of Vacccine Passport. This will be the beginning of the end of freedom as we know it. Chained to a system, of THIER making, with no escape. No one wins, EVERYONE will lose! See the bigger picture!!
# 2  @Carolramsden6 @RF_Jenkins @zoeharcombe How about doing some serious research? I suggest start with Cutter incident. It’s what put loads of vaxxed people into the iron lungs. Contaminated polio vaccine. And don’t stop there. Keep digging.
# 3  https://t.co/WnqWXs4uKS
# 4  I don’t take medical advice from anybody who has ever publicly advocated human depopulation.
#
#                                                         tweet_url  \
# 0  https://twitter.com/Nathalienath19/status/1377517270667255810
# 1  https://twitter.com/Manmadeimage/status/1377517723798888448
# 2  https://twitter.com/naomirowling/status/1377520752006664192
# 3  https://twitter.com/mandyjanevernon/status/1377517881601224704
# 4  https://twitter.com/GeorgeS21302455/status/1377520887247814656
#
#                   user_created_at              user_id  \
# 0  Wed Mar 11 20:09:45 +0000 2020  1237833052170194944
# 1  Sun Mar 13 21:13:03 +0000 2011  265604134
# 2  Tue Sep 29 15:09:09 +0000 2009  78333947
# 3  Wed Dec 30 19:37:40 +0000 2015  4657017676
# 4  Mon Jul 10 14:35:21 +0000 2017  884420782155120640
#
#    user_default_profile_image  \
# 0  False
# 1  False
# 2  False
# 3  True
# 4  True
#
#                                                                                                                                                  user_description  \
# 0  @NathalieI -- Parler\n@Nathalienath19 -- solidaritia\n@Nathalienath19 -tme
# 1  Each person is a prisoner unto themselves. We're being imprisoned by a scientific and materialistic world. The awakened see it as a prison , others normality.
# 2  Artistic essential oil expert, nomad and owner of a Spanish olive grove
# 3  NaN
# 4  NaN
#
#    user_favourites_count  user_followers_count  user_friends_count  \
# 0  27930                  430                   779
# 1  1453                   31                    92
# 2  889                    91                    290
# 3  126525                 1183                  4986
# 4  42285                  435                   1024
#
#    user_listed_count       user_location      user_name user_screen_name  \
# 0  0                  en quête de vérité  Nath La louve  Nathalienath19
# 1  0                  NaN                 Scoot #KBF     Manmadeimage
# 2  1                  NaN                 Naomi Rowling  naomirowling
# 3  69                 NaN                 Amanda Vernon  mandyjanevernon
# 4  0                  NaN                 George S       GeorgeS21302455
#
#    user_statuses_count  user_time_zone                user_urls  user_verified
# 0  23029               NaN              NaN                      False
# 1  2053                NaN              NaN                      False
# 2  456                 NaN              http://naomirowling.com  False
# 3  158247              NaN              NaN                      False
# 4  36506               NaN              NaN                      False

# %%
hydrated_2021_04.shape
# Out:
# (386169, 35)

# %%
# concatenate dfs

vax_full = pd.concat([hydrated_2020_11, hydrated_2020_12, hydrated_2021_01, 
           hydrated_2021_02, hydrated_2021_03, hydrated_2021_04],
         ignore_index=True)
vax_full.head()
# Out:
#   coordinates                      created_at hashtags media  \
# 0  NaN         Sun Nov 01 07:04:54 +0000 2020  NaN      NaN
# 1  NaN         Sun Nov 01 07:10:02 +0000 2020  NaN      NaN
# 2  NaN         Sun Nov 01 07:13:25 +0000 2020  NaN      NaN
# 3  NaN         Sun Nov 01 07:31:24 +0000 2020  NaN      NaN
# 4  NaN         Sun Nov 01 07:01:51 +0000 2020  NaN      NaN
#
#                                                        urls  favorite_count  \
# 0  https://twitter.com/LotusOak2/status/1322642287449591814  0
# 1  NaN                                                       0
# 2  NaN                                                       0
# 3  NaN                                                       0
# 4  NaN                                                       1
#
#                     id in_reply_to_screen_name  in_reply_to_status_id  \
# 0  1322796743298265088  NaN                    NaN
# 1  1322798033596272640  NaN                    NaN
# 2  1322798887694905346  NaN                    NaN
# 3  1322803412300431361  NaN                    NaN
# 4  1322795973337403395  bongzmessi              1.322170e+18
#
#    in_reply_to_user_id lang place possibly_sensitive      quote_id  \
# 0 NaN                   en   NaN   False              1.322642e+18
# 1 NaN                   en   NaN   NaN               NaN
# 2 NaN                   en   NaN   NaN               NaN
# 3 NaN                   en   NaN   NaN                1.322434e+18
# 4  217711495.0          en   NaN   NaN               NaN
#
#    retweet_count    retweet_id retweet_screen_name  \
# 0  0             NaN            NaN
# 1  489            1.322434e+18  sunnynwaobi1
# 2  122            1.322792e+18  conspiracyb0t
# 3  41             1.322774e+18  Onyinye51838197
# 4  0             NaN            NaN
#
#                                                                                  source  \
# 0  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 1  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 2  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#                                                                                                                                                                                                                                                                                                   text  \
# 0  Stay away from that vaccine. Population control. https://t.co/DTMFGsNRzX
# 1  Isn't this a systematic depopulation happing in Obigbo?, where young unarmed citizens are randomly picked, some tortured while some are killed. #Obigbomassacre @StateDept @AmnestyNigeria @ https://t.co/TsakU0l3Fm
# 2  Bill Gates is one of the biggest proponents of mass depopulation.
# 3  The world should be on notice that Nelson nwike river state governor and the Nigeria army are committing genocide and pogrom in Biafra land https://t.co/fTC8gNNSsZ
# 4  @bongzmessi To come to think of it perhaps this was done so they multiply and outnumber us but. To them the depopulation agenda is at top of their list. Phela my King bake baphahluke labantu telling things they were not supposed like the one on an interview that they injected AIDS to blacks
#
#                                                         tweet_url  \
# 0  https://twitter.com/BAChatwin/status/1322796743298265088
# 1  https://twitter.com/jumoke_ladan/status/1322798033596272640
# 2  https://twitter.com/wambo161/status/1322798887694905346
# 3  https://twitter.com/EmmanuelNwanyim/status/1322803412300431361
# 4  https://twitter.com/Boniswa63207956/status/1322795973337403395
#
#                   user_created_at              user_id  \
# 0  Mon Sep 19 17:13:57 +0000 2011  376304718
# 1  Wed Jul 01 19:30:15 +0000 2009  52824297
# 2  Fri Apr 08 16:05:41 +0000 2011  279106686
# 3  Tue Apr 21 07:16:59 +0000 2020  1252496422865375238
# 4  Mon May 25 12:43:06 +0000 2020  1264899714950062080
#
#    user_default_profile_image  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                                                                                                           user_description  \
# 0  ☀️🇨🇦🌍Truth☀️🇨🇦🌍 Freedom ☀️🇨🇦🌏Health ☀️🇨🇦🌍Eyes wide open\nAwake patriot and CF veteran (13+yrs)
# 1  Am a Christian by God's grace. Called by Christ to serve and love Him as a Catholic. Perpetually loving Him.
# 2  Follower of Jesus.
# 3  i was born to shine take it or live it...blessed son by God in heaven..🙌🏼🙌🏼🙌🏼..peace 👍🏻 ...Biafran citizen Israel 🇮🇱 citizen
# 4  Mayibuye iAfrika✊🏾. \n\nI don't call my people Kings and Queens to tickle my throat it's because we are Royalty 👸🏾🤴🏿.\nTribalism 🤮Feminism 🤮Xenophobia🤮
#
#    user_favourites_count  user_followers_count  user_friends_count  \
# 0  1643                   130                   658
# 1  7009                   224                   359
# 2  27413                  205                   711
# 3  8947                   121                   307
# 4  39392                  3658                  3680
#
#    user_listed_count         user_location              user_name  \
# 0  0                  Niagara, Ontario      Barb Chatwin
# 1  1                  Lagos, Nigeria        Olajumoke Ladan
# 2  3                   la montaña de roble  James of Oak Mountain
# 3  1                  Israel                Emmanuel nwanyim
# 4  2                  NaN                   Boniswa
#
#   user_screen_name  user_statuses_count  user_time_zone user_urls  \
# 0  BAChatwin        2659                NaN              NaN
# 1  jumoke_ladan     1812                NaN              NaN
# 2  wambo161         48229               NaN              NaN
# 3  EmmanuelNwanyim  16345               NaN              NaN
# 4  Boniswa63207956  40107               NaN              NaN
#
#    user_verified
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
# almost 1.1 million rows of tweets

vax_full.shape
# Out:
# (1099909, 35)

# %% [markdown]
# ## Exploring the combined dataset

# %%
vax_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1099909 entries, 0 to 1099908
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   coordinates                 239 non-null      object
#  1   created_at                  1099909 non-null  object
#  2   hashtags                    163543 non-null   object
#  3   media                       85056 non-null    object
#  4   urls                        240801 non-null   object
#  5   favorite_count              1099909 non-null  int64
#  6   id                          1099909 non-null  int64
#  7   in_reply_to_screen_name     234118 non-null   object
#  8   in_reply_to_status_id       225351 non-null   float64
#  9   in_reply_to_user_id         234118 non-null   float64
#  10  lang                        1099909 non-null  object
#  11  place                       8677 non-null     object
#  12  possibly_sensitive          313108 non-null   object
#  13  quote_id                    292572 non-null   float64
#  14  retweet_count               1099909 non-null  int64
#  15  retweet_id                  640621 non-null   float64
#  16  retweet_screen_name         640621 non-null   object
#  17  source                      1099909 non-null  object
#  18  text                        1099909 non-null  object
#  19  tweet_url                   1099909 non-null  object
#  20  user_created_at             1099909 non-null  object
#  21  user_id                     1099909 non-null  int64
#  22  user_default_profile_image  1099909 non-null  bool
#  23  user_description            922461 non-null   object
#  24  user_favourites_count       1099909 non-null  int64
#  25  user_followers_count        1099909 non-null  int64
#  26  user_friends_count          1099909 non-null  int64
#  27  user_listed_count           1099909 non-null  int64
#  28  user_location               706234 non-null   object
#  29  user_name                   1099798 non-null  object
#  30  user_screen_name            1099908 non-null  object
#  31  user_statuses_count         1099909 non-null  int64
#  32  user_time_zone              0 non-null        float64
#  33  user_urls                   244733 non-null   object
#  34  user_verified               1099909 non-null  bool
# dtypes: bool(2), float64(5), int64(9), object(19)
# memory usage: 279.0+ MB

# %%
# convert quote_id and retweet_id to int (in order to suppress scientific notation)

vax_full['quote_id'] = vax_full['quote_id'].astype('Int64')
vax_full['retweet_id'] = vax_full['retweet_id'].astype('Int64')

# %%
vax_full.head()
# Out:
#   coordinates                      created_at hashtags media  \
# 0  NaN         Sun Nov 01 07:04:54 +0000 2020  NaN      NaN
# 1  NaN         Sun Nov 01 07:10:02 +0000 2020  NaN      NaN
# 2  NaN         Sun Nov 01 07:13:25 +0000 2020  NaN      NaN
# 3  NaN         Sun Nov 01 07:31:24 +0000 2020  NaN      NaN
# 4  NaN         Sun Nov 01 07:01:51 +0000 2020  NaN      NaN
#
#                                                        urls  favorite_count  \
# 0  https://twitter.com/LotusOak2/status/1322642287449591814  0
# 1  NaN                                                       0
# 2  NaN                                                       0
# 3  NaN                                                       0
# 4  NaN                                                       1
#
#                     id in_reply_to_screen_name  in_reply_to_status_id  \
# 0  1322796743298265088  NaN                    NaN
# 1  1322798033596272640  NaN                    NaN
# 2  1322798887694905346  NaN                    NaN
# 3  1322803412300431361  NaN                    NaN
# 4  1322795973337403395  bongzmessi              1.322170e+18
#
#    in_reply_to_user_id lang place possibly_sensitive             quote_id  \
# 0 NaN                   en   NaN   False              1322642287449591808
# 1 NaN                   en   NaN   NaN                <NA>
# 2 NaN                   en   NaN   NaN                <NA>
# 3 NaN                   en   NaN   NaN                1322434241829982208
# 4  217711495.0          en   NaN   NaN                <NA>
#
#    retweet_count           retweet_id retweet_screen_name  \
# 0  0              <NA>                 NaN
# 1  489            1322434241829982208  sunnynwaobi1
# 2  122            1322791741854937088  conspiracyb0t
# 3  41             1322774415873052672  Onyinye51838197
# 4  0              <NA>                 NaN
#
#                                                                                  source  \
# 0  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 1  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 2  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#                                                                                                                                                                                                                                                                                                   text  \
# 0  Stay away from that vaccine. Population control. https://t.co/DTMFGsNRzX
# 1  Isn't this a systematic depopulation happing in Obigbo?, where young unarmed citizens are randomly picked, some tortured while some are killed. #Obigbomassacre @StateDept @AmnestyNigeria @ https://t.co/TsakU0l3Fm
# 2  Bill Gates is one of the biggest proponents of mass depopulation.
# 3  The world should be on notice that Nelson nwike river state governor and the Nigeria army are committing genocide and pogrom in Biafra land https://t.co/fTC8gNNSsZ
# 4  @bongzmessi To come to think of it perhaps this was done so they multiply and outnumber us but. To them the depopulation agenda is at top of their list. Phela my King bake baphahluke labantu telling things they were not supposed like the one on an interview that they injected AIDS to blacks
#
#                                                         tweet_url  \
# 0  https://twitter.com/BAChatwin/status/1322796743298265088
# 1  https://twitter.com/jumoke_ladan/status/1322798033596272640
# 2  https://twitter.com/wambo161/status/1322798887694905346
# 3  https://twitter.com/EmmanuelNwanyim/status/1322803412300431361
# 4  https://twitter.com/Boniswa63207956/status/1322795973337403395
#
#                   user_created_at              user_id  \
# 0  Mon Sep 19 17:13:57 +0000 2011  376304718
# 1  Wed Jul 01 19:30:15 +0000 2009  52824297
# 2  Fri Apr 08 16:05:41 +0000 2011  279106686
# 3  Tue Apr 21 07:16:59 +0000 2020  1252496422865375238
# 4  Mon May 25 12:43:06 +0000 2020  1264899714950062080
#
#    user_default_profile_image  \
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
#                                                                                                                                           user_description  \
# 0  ☀️🇨🇦🌍Truth☀️🇨🇦🌍 Freedom ☀️🇨🇦🌏Health ☀️🇨🇦🌍Eyes wide open\nAwake patriot and CF veteran (13+yrs)
# 1  Am a Christian by God's grace. Called by Christ to serve and love Him as a Catholic. Perpetually loving Him.
# 2  Follower of Jesus.
# 3  i was born to shine take it or live it...blessed son by God in heaven..🙌🏼🙌🏼🙌🏼..peace 👍🏻 ...Biafran citizen Israel 🇮🇱 citizen
# 4  Mayibuye iAfrika✊🏾. \n\nI don't call my people Kings and Queens to tickle my throat it's because we are Royalty 👸🏾🤴🏿.\nTribalism 🤮Feminism 🤮Xenophobia🤮
#
#    user_favourites_count  user_followers_count  user_friends_count  \
# 0  1643                   130                   658
# 1  7009                   224                   359
# 2  27413                  205                   711
# 3  8947                   121                   307
# 4  39392                  3658                  3680
#
#    user_listed_count         user_location              user_name  \
# 0  0                  Niagara, Ontario      Barb Chatwin
# 1  1                  Lagos, Nigeria        Olajumoke Ladan
# 2  3                   la montaña de roble  James of Oak Mountain
# 3  1                  Israel                Emmanuel nwanyim
# 4  2                  NaN                   Boniswa
#
#   user_screen_name  user_statuses_count  user_time_zone user_urls  \
# 0  BAChatwin        2659                NaN              NaN
# 1  jumoke_ladan     1812                NaN              NaN
# 2  wambo161         48229               NaN              NaN
# 3  EmmanuelNwanyim  16345               NaN              NaN
# 4  Boniswa63207956  40107               NaN              NaN
#
#    user_verified
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
vax_full.shape
# Out:
# (1099909, 35)

# %% [markdown]
# ### Retweets

# %%
# more than half the 1.1 million tweets are re-tweets

(~(vax_full['retweet_id'].isnull())).sum()
# Out:
# 640621

# %%
vax_full['retweet_id'].nunique()
# Out:
# 75980

# %%
# the most common retweets

vax_full.groupby('retweet_id')['retweet_id'].count(). \
sort_values(ascending=False).head(10)
# Out:
# retweet_id
# 1379184293138857984    27902
# 1346602188953559040    20326
# 1379832806902206464    14516
# 1366957856323469312    6836
# 1379200046957215744    6743
# 1370200113977700352    5376
# 1342085913782923264    4683
# 1375160759324352512    3972
# 1349810559986839552    3962
# 1380906061813661696    3506
# Name: retweet_id, dtype: int64

# %%
# looks like retweeet text is all identical - makes sense
# not that this tweet w/ 27K re-tweets is actually pro-vaccine
# keyword was probably "vaxxed"

vax_full[vax_full['retweet_id'] == 1379184293138857984]
# Out:
#         coordinates                      created_at hashtags media urls  \
# 788525   NaN         Mon Apr 05 21:30:18 +0000 2021  NaN      NaN   NaN
# 788526   NaN         Mon Apr 05 21:33:34 +0000 2021  NaN      NaN   NaN
# 788539   NaN         Mon Apr 05 21:31:23 +0000 2021  NaN      NaN   NaN
# 788545   NaN         Mon Apr 05 21:32:04 +0000 2021  NaN      NaN   NaN
# 788549   NaN         Mon Apr 05 21:29:44 +0000 2021  NaN      NaN   NaN
# ...      ...                                    ...  ...      ...   ...
# 1082848  NaN         Tue Apr 20 00:47:58 +0000 2021  NaN      NaN   NaN
# 1083946  NaN         Tue Apr 20 03:01:09 +0000 2021  NaN      NaN   NaN
# 1085584  NaN         Tue Apr 20 07:08:29 +0000 2021  NaN      NaN   NaN
# 1090387  NaN         Tue Apr 20 16:26:06 +0000 2021  NaN      NaN   NaN
# 1091704  NaN         Tue Apr 20 17:57:02 +0000 2021  NaN      NaN   NaN
#
#          favorite_count                   id in_reply_to_screen_name  \
# 788525   0               1379184647670730753  NaN
# 788526   0               1379185470442201097  NaN
# 788539   0               1379184920153649153  NaN
# 788545   0               1379185090123694083  NaN
# 788549   0               1379184504837902337  NaN
# ...     ..                               ...  ...
# 1082848  0               1384307823417303041  NaN
# 1083946  0               1384341339702235143  NaN
# 1085584  0               1384403582158479362  NaN
# 1090387  0               1384543908655517698  NaN
# 1091704  0               1384566793985937413  NaN
#
#          in_reply_to_status_id  in_reply_to_user_id lang place  \
# 788525  NaN                    NaN                   en   NaN
# 788526  NaN                    NaN                   en   NaN
# 788539  NaN                    NaN                   en   NaN
# 788545  NaN                    NaN                   en   NaN
# 788549  NaN                    NaN                   en   NaN
# ...      ..                     ..                   ..   ...
# 1082848 NaN                    NaN                   en   NaN
# 1083946 NaN                    NaN                   en   NaN
# 1085584 NaN                    NaN                   en   NaN
# 1090387 NaN                    NaN                   en   NaN
# 1091704 NaN                    NaN                   en   NaN
#
#         possibly_sensitive  quote_id  retweet_count           retweet_id  \
# 788525   NaN                <NA>      36735          1379184293138857984
# 788526   NaN                <NA>      36735          1379184293138857984
# 788539   NaN                <NA>      36735          1379184293138857984
# 788545   NaN                <NA>      36735          1379184293138857984
# 788549   NaN                <NA>      36735          1379184293138857984
# ...      ...                 ...        ...                          ...
# 1082848  NaN                <NA>      36735          1379184293138857984
# 1083946  NaN                <NA>      36735          1379184293138857984
# 1085584  NaN                <NA>      36735          1379184293138857984
# 1090387  NaN                <NA>      36735          1379184293138857984
# 1091704  NaN                <NA>      36735          1379184293138857984
#
#         retweet_screen_name  \
# 788525   GrillmoreSlim
# 788526   GrillmoreSlim
# 788539   GrillmoreSlim
# 788545   GrillmoreSlim
# 788549   GrillmoreSlim
# ...                ...
# 1082848  GrillmoreSlim
# 1083946  GrillmoreSlim
# 1085584  GrillmoreSlim
# 1090387  GrillmoreSlim
# 1091704  GrillmoreSlim
#
#                                                                                        source  \
# 788525   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 788526   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 788539   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 788545   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 788549   <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...                                                                                     ...
# 1082848  <a href="http://www.echofon.com/" rel="nofollow">Echofon</a>
# 1083946  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1085584  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 1090387  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1091704  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                                    text  \
# 788525   This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
# 788526   This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
# 788539   This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
# 788545   This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
# 788549   This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
# ...                                                                                                                                                 ...
# 1082848  This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
# 1083946  This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
# 1085584  This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
# 1090387  This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
# 1091704  This lady on the plane said "vaxxed and waxed, baby, I'm ready for some action on this trip." and that should be everybody's vibe this summer.
#
#                                                               tweet_url  \
# 788525   https://twitter.com/lilakeys21/status/1379184647670730753
# 788526   https://twitter.com/50sombrasdegris/status/1379185470442201097
# 788539   https://twitter.com/trusttheunseen/status/1379184920153649153
# 788545   https://twitter.com/_FefeXO/status/1379185090123694083
# 788549   https://twitter.com/BryanVillone/status/1379184504837902337
# ...                                                              ...
# 1082848  https://twitter.com/drollpatrol/status/1384307823417303041
# 1083946  https://twitter.com/kaushiiveeno/status/1384341339702235143
# 1085584  https://twitter.com/whathefaz/status/1384403582158479362
# 1090387  https://twitter.com/trcpicalove/status/1384543908655517698
# 1091704  https://twitter.com/kimmiequuzz/status/1384566793985937413
#
#                         user_created_at             user_id  \
# 788525   Tue Jul 27 01:28:03 +0000 2010  171298581
# 788526   Mon May 12 22:42:57 +0000 2014  2543923811
# 788539   Tue Jul 31 02:40:25 +0000 2012  727391077
# 788545   Thu Jul 02 02:40:10 +0000 2009  52942895
# 788549   Thu Jan 29 17:21:23 +0000 2009  19721340
# ...                                 ...       ...
# 1082848  Thu Dec 17 16:26:27 +0000 2009  97475545
# 1083946  Fri Apr 01 20:23:42 +0000 2011  275697595
# 1085584  Mon Aug 16 06:05:35 +0000 2010  178989564
# 1090387  Fri Sep 22 22:14:24 +0000 2017  911353010957246466
# 1091704  Mon Dec 27 00:14:07 +0000 2010  230882056
#
#          user_default_profile_image  \
# 788525   False
# 788526   False
# 788539   False
# 788545   False
# 788549   False
# ...        ...
# 1082848  False
# 1083946  False
# 1085584  False
# 1090387  False
# 1091704  False
#
#                                                                                                                                                                        user_description  \
# 788525   NaN
# 788526   becoming my better self / 🇵🇷
# 788539   Simply blessed.
# 788545   25| cerified lover girl. 🏳️‍🌈🇵🇷 | Cancer 🌞Leo 🌛Capricorn Asc
# 788549   Stand Up Comedian. Cheapskate. IG: BryanVillone
# ...                                                  ...
# 1082848  Black Lives Matter (https://t.co/IVcaM20Hrc)\n\nSocial Distancing Expert\n\nKing Lear Act 4 Scene 6 Line 60\n\nShe/her\n\nCashApp $DrollPatrol\n\n\n(Painting by Kyra Kendall)
# 1083946  can neither confirm or deny that im a gemini
# 1085584  Positive outcomes only. #CODEBLACKMY\n#PelajarBukanPengantin #SchoolNotSpouse #MigranJugaManusia #PrayforPalestine #PrayforMyanmar #HutanPergiMana
# 1090387  i solve my problems by blatantly ignoring them and going on the internet
# 1091704  NaN
#
#          user_favourites_count  user_followers_count  user_friends_count  \
# 788525   2293                   1297                  1104
# 788526   13477                  593                   443
# 788539   12505                  922                   865
# 788545   33196                  941                   507
# 788549   191                    399                   200
# ...      ...                    ...                   ...
# 1082848  18183                  410                   1348
# 1083946  46157                  279                   193
# 1085584  205767                 553                   94
# 1090387  3753                   16                    100
# 1091704  25943                  151                   138
#
#          user_listed_count           user_location  \
# 788525   3                  Jersey
# 788526   3                  enrique 💍
# 788539   0                  NaN
# 788545   10                 Texas, USA
# 788549   9                  NJ
# ...     ..                  ..
# 1082848  38                 Inner World
# 1083946  2                  tor-iunno
# 1085584  3                  NaN
# 1090387  0                  she/her | 23 | hungary
# 1091704  6                  NaN
#
#                                       user_name user_screen_name  \
# 788525   The Cunt Conductor                      lilakeys21
# 788526   grey 🌪                                  50sombrasdegris
# 788539   E                                       trusttheunseen
# 788545   CHAMPAGNE MAMÍ✨                         _FefeXO
# 788549   Global megastar. Hero to many peasant.  BryanVillone
# ...                                         ...           ...
# 1082848  Delagrammatikas                         drollpatrol
# 1083946  ♔ kay ♔                                 kaushiiveeno
# 1085584  Faz                                     whathefaz
# 1090387  mónika 🥀                                trcpicalove
# 1091704  Kimberly                                kimmiequuzz
#
#          user_statuses_count  user_time_zone  \
# 788525   99162               NaN
# 788526   20423               NaN
# 788539   23382               NaN
# 788545   94389               NaN
# 788549   28458               NaN
# ...        ...                ..
# 1082848  13632               NaN
# 1083946  20926               NaN
# 1085584  153716              NaN
# 1090387  8927                NaN
# 1091704  19297               NaN
#
#                                                                                user_urls  \
# 788525   NaN
# 788526   NaN
# 788539   NaN
# 788545   NaN
# 788549   https://www.eventbrite.com/e/down-to-the-last-bit-tickets-167885274375?ref=eios
# ...                                                                                  ...
# 1082848  NaN
# 1083946  NaN
# 1085584  http://instagram.com/faz367_
# 1090387  NaN
# 1091704  NaN
#
#          user_verified
# 788525   False
# 788526   False
# 788539   False
# 788545   False
# 788549   False
# ...        ...
# 1082848  False
# 1083946  False
# 1085584  False
# 1090387  False
# 1091704  False
#
# [27902 rows x 35 columns]

# %% [markdown]
# ### Quote tweets

# %%
# 292K out of 1.1 million tweets are quotes

(~(vax_full['quote_id'].isnull())).sum()
# Out:
# 292572

# %%
# 156K are both quotes and retweets

((~(vax_full['quote_id'].isnull())) & \
(~(vax_full['retweet_id'].isnull()))).sum()
# Out:
# 156634

# %%
# the most common quote tweets

vax_full.groupby('quote_id')['quote_id'].count(). \
sort_values(ascending=False).head(10)
# Out:
# quote_id
# 1346525695879614464    20486
# 1372504222248415232    3809
# 1377647623339905024    2990
# 1342085913782923264    2815
# 1379184293138857984    2400
# 1333129526826721280    2160
# 1362783010597310464    2072
# 1346602188953559040    1879
# 1370735174137298944    1777
# 1380606469004009472    1676
# Name: quote_id, dtype: int64

# %%
# looks like quote tweets are sometimes identical, but sometimes not

vax_full[vax_full['quote_id'] == 1346525695879614464].head(10)
# Out:
#        coordinates                      created_at hashtags media  \
# 137165  NaN         Tue Jan 05 20:17:37 +0000 2021  NaN      NaN
# 137185  NaN         Tue Jan 05 20:22:37 +0000 2021  NaN      NaN
# 137199  NaN         Tue Jan 05 20:17:56 +0000 2021  NaN      NaN
# 137201  NaN         Tue Jan 05 20:18:33 +0000 2021  NaN      NaN
# 137219  NaN         Tue Jan 05 20:36:39 +0000 2021  NaN      NaN
# 137225  NaN         Tue Jan 05 20:37:37 +0000 2021  NaN      NaN
# 137227  NaN         Tue Jan 05 20:38:35 +0000 2021  NaN      NaN
# 137228  NaN         Tue Jan 05 20:48:25 +0000 2021  NaN      NaN
# 137234  NaN         Tue Jan 05 20:36:22 +0000 2021  NaN      NaN
# 137235  NaN         Tue Jan 05 20:37:34 +0000 2021  NaN      NaN
#
#                                                              urls  \
# 137165  https://twitter.com/therecount/status/1346525695879614467
# 137185  NaN
# 137199  NaN
# 137201  NaN
# 137219  NaN
# 137225  NaN
# 137227  NaN
# 137228  NaN
# 137234  https://twitter.com/therecount/status/1346525695879614467
# 137235  NaN
#
#         favorite_count                   id in_reply_to_screen_name  \
# 137165  23              1346551449199775746  NaN
# 137185  0               1346552706006040576  NaN
# 137199  0               1346551528849633280  NaN
# 137201  0               1346551683598446598  NaN
# 137219  0               1346556235764535299  NaN
# 137225  0               1346556482683285504  NaN
# 137227  0               1346556723423801346  NaN
# 137228  0               1346559198247727110  NaN
# 137234  157             1346556164214054918  NaN
# 137235  0               1346556469362249728  NaN
#
#         in_reply_to_status_id  in_reply_to_user_id lang place  \
# 137165 NaN                    NaN                   en   NaN
# 137185 NaN                    NaN                   en   NaN
# 137199 NaN                    NaN                   en   NaN
# 137201 NaN                    NaN                   en   NaN
# 137219 NaN                    NaN                   en   NaN
# 137225 NaN                    NaN                   en   NaN
# 137227 NaN                    NaN                   en   NaN
# 137228 NaN                    NaN                   en   NaN
# 137234 NaN                    NaN                   en   NaN
# 137235 NaN                    NaN                   en   NaN
#
#        possibly_sensitive             quote_id  retweet_count  \
# 137165  False              1346525695879614464  4
# 137185  NaN                1346525695879614464  4
# 137199  NaN                1346525695879614464  4
# 137201  NaN                1346525695879614464  4
# 137219  NaN                1346525695879614464  43
# 137225  NaN                1346525695879614464  43
# 137227  NaN                1346525695879614464  43
# 137228  NaN                1346525695879614464  43
# 137234  False              1346525695879614464  43
# 137235  NaN                1346525695879614464  43
#
#                  retweet_id retweet_screen_name  \
# 137165  <NA>                 NaN
# 137185  1346551449199775744  RGibsongirl
# 137199  1346551449199775744  RGibsongirl
# 137201  1346551449199775744  RGibsongirl
# 137219  1346556164214054912  LouisatheLast
# 137225  1346556164214054912  LouisatheLast
# 137227  1346556164214054912  LouisatheLast
# 137228  1346556164214054912  LouisatheLast
# 137234  <NA>                 NaN
# 137235  1346556164214054912  LouisatheLast
#
#                                                                                       source  \
# 137165  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 137185  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 137199  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 137201  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 137219  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 137225  <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 137227  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 137228  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 137234  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 137235  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
#
#                                                                                                                                                                                                                 text  \
# 137165  Yeah, because what you *REALLY* want is unvaccinated people handling the food supply because they don't have citizenship paperwork. 🙄🙄🙄🙄🙄 https://t.co/4gfG58eEK1
# 137185  Yeah, because what you *REALLY* want is unvaccinated people handling the food supply because they don't have citizenship paperwork. 🙄🙄🙄🙄🙄 https://t.co/4gfG58eEK1
# 137199  Yeah, because what you *REALLY* want is unvaccinated people handling the food supply because they don't have citizenship paperwork. 🙄🙄🙄🙄🙄 https://t.co/4gfG58eEK1
# 137201  Yeah, because what you *REALLY* want is unvaccinated people handling the food supply because they don't have citizenship paperwork. 🙄🙄🙄🙄🙄 https://t.co/4gfG58eEK1
# 137219  This is ridiculous. Do you want sick people handling your food? Do you think vaccines work so perfectly that unvaccinated workers won’t get vaccinated coworkers sick? What the fuck https://t.co/oBA9x2ji83
# 137225  This is ridiculous. Do you want sick people handling your food? Do you think vaccines work so perfectly that unvaccinated workers won’t get vaccinated coworkers sick? What the fuck https://t.co/oBA9x2ji83
# 137227  This is ridiculous. Do you want sick people handling your food? Do you think vaccines work so perfectly that unvaccinated workers won’t get vaccinated coworkers sick? What the fuck https://t.co/oBA9x2ji83
# 137228  This is ridiculous. Do you want sick people handling your food? Do you think vaccines work so perfectly that unvaccinated workers won’t get vaccinated coworkers sick? What the fuck https://t.co/oBA9x2ji83
# 137234  This is ridiculous. Do you want sick people handling your food? Do you think vaccines work so perfectly that unvaccinated workers won’t get vaccinated coworkers sick? What the fuck https://t.co/oBA9x2ji83
# 137235  This is ridiculous. Do you want sick people handling your food? Do you think vaccines work so perfectly that unvaccinated workers won’t get vaccinated coworkers sick? What the fuck https://t.co/oBA9x2ji83
#
#                                                              tweet_url  \
# 137165  https://twitter.com/RGibsongirl/status/1346551449199775746
# 137185  https://twitter.com/Jerri_Lynn25/status/1346552706006040576
# 137199  https://twitter.com/SilviPastured/status/1346551528849633280
# 137201  https://twitter.com/dalydes/status/1346551683598446598
# 137219  https://twitter.com/aboynamedart/status/1346556235764535299
# 137225  https://twitter.com/SouthrnGothHick/status/1346556482683285504
# 137227  https://twitter.com/bunrxm/status/1346556723423801346
# 137228  https://twitter.com/SamanthaEich/status/1346559198247727110
# 137234  https://twitter.com/LouisatheLast/status/1346556164214054918
# 137235  https://twitter.com/ForthWyn/status/1346556469362249728
#
#                        user_created_at              user_id  \
# 137165  Fri Nov 20 20:57:15 +0000 2009  91423884
# 137185  Sat Nov 09 03:16:22 +0000 2019  1193004107759529986
# 137199  Sat Feb 22 17:32:01 +0000 2020  1231270345300160518
# 137201  Sun Apr 03 16:08:33 +0000 2011  276555350
# 137219  Sun Nov 23 23:11:55 +0000 2008  17580293
# 137225  Sun Jul 04 02:01:47 +0000 2010  162566080
# 137227  Tue Nov 24 00:36:59 +0000 2009  92157633
# 137228  Sat Nov 05 05:26:19 +0000 2011  405338829
# 137234  Tue Dec 02 00:47:39 +0000 2008  17794636
# 137235  Sat May 30 16:24:25 +0000 2009  43551122
#
#         user_default_profile_image  \
# 137165  False
# 137185  False
# 137199  False
# 137201  False
# 137219  False
# 137225  False
# 137227  False
# 137228  False
# 137234  False
# 137235  False
#
#                                                                                                                                                              user_description  \
# 137165  Corset scholar; bioanth PhD; chaotic neutral--harlequin aspect; bibliophile; tattoo collector; advocate for the dead; robot sex analyst; bad example for hire.
# 137185  “𝒯𝒽𝑒 𝓃𝑒𝓍𝓉 𝓉𝒾𝓂𝑒 𝓈𝑜𝓂𝑒𝑜𝓃𝑒‘𝓈 𝓉𝑒𝒶𝒸𝒽𝒾𝓃𝑔, 𝓌𝒽𝓎 𝒹𝑜𝓃‘𝓉 𝓎𝑜𝓊 𝑔𝑒𝓉 𝓉𝒶𝓊𝑔𝒽𝓉?“
# 137199  Settler focused on Earth Service via climate-resilient food security.\n\n#NoPrideInGenocide #LandBack\n\n#KeepItInTheGround #ClimateStrike #Divest #FoodNotLawns
# 137201  Attempting to ally.  #BLMTO  #wetsuwetenstrong  #MMIW  #RightsnotRescue  #Antifa  Dish with One Spoon  He/his
# 137219  Team @erumors. He/His. @Racialicious Forever. Bylines: SyfyWire, Motherboard, Rolling Stone, Raw Story. Notorious anti-white racist.' -- Breitbart
# 137225  Paul\n\nbisexual with an aquarium. might be scotts irish?\n|\nstudied Latin & gender; now, studies biochem\n|\nlikes: peppers, snakes, & spiders\n|\nThey/Them/Y'all.
# 137227  enby bun. they/them. 🐰🤓🤖
# 137228  librarian, couch potato, very enthusiastic talker | she/her
# 137234  Big mean sweaty dyke just looking for trouble. Friend of Garak. Cis-ish, she/her, graphic designer, race traitor, obesity glorifier. Opinions all mine. 🌹🍞🌹
# 137235  Eve, 26, fantasy writer, web developer in training, Salford Uni graduate. She/her
#
#         user_favourites_count  user_followers_count  user_friends_count  \
# 137165  117226                 5616                  6176
# 137185  109620                 5219                  2887
# 137199  192627                 1335                  2350
# 137201  176444                 892                   4373
# 137219  44646                  4103                  4810
# 137225  334002                 1319                  2679
# 137227  167918                 1937                  1945
# 137228  3924                   131                   251
# 137234  334406                 33261                 2127
# 137235  41385                  575                   1958
#
#         user_listed_count     user_location  \
# 137165  16                 NaN
# 137185  7                  Here & There
# 137199  13                 So-called Canada
# 137201  42                 Toronto
# 137219  217                NaN
# 137225  2                  Alabama
# 137227  9                  ¯\_(ツ)_/¯
# 137228  1                  a comfy chair
# 137234  236                NaN
# 137235  35                 England
#
#                                       user_name user_screen_name  \
# 137165  Dr. Rebecca Gibson                       RGibsongirl
# 137185  JerriLynn                                Jerri_Lynn25
# 137199  Practice Courage                         SilviPastured
# 137201  mind that magnifies the smallest matter  dalydes
# 137219  Arturo R. Garcia                         aboynamedart
# 137225  crass iron skillet                       SouthrnGothHick
# 137227  rxbun                                    bunrxm
# 137228  Samantha 🏳️‍🌈                            SamanthaEich
# 137234  Louisa 🌈👭                                LouisatheLast
# 137235  📖Eve (she/her)                           ForthWyn
#
#         user_statuses_count  user_time_zone  \
# 137165  42698               NaN
# 137185  72221               NaN
# 137199  103084              NaN
# 137201  87929               NaN
# 137219  153723              NaN
# 137225  125234              NaN
# 137227  994275              NaN
# 137228  5894                NaN
# 137234  193614              NaN
# 137235  100540              NaN
#
#                                               user_urls  user_verified
# 137165  http://amazon.com/author/rebeccagibsonbioanthro  False
# 137185  NaN                                              False
# 137199  NaN                                              False
# 137201  NaN                                              False
# 137219  http://racialicious.com                          False
# 137225  NaN                                              False
# 137227  NaN                                              False
# 137228  NaN                                              False
# 137234  NaN                                              False
# 137235  NaN                                              False

# %% [markdown]
# ### Language

# %%
# most are in English, but not all

vax_full['lang'].value_counts()
# Out:
# en     991130
# und    53757
# fr     12193
# es     7604
# ja     5112
# de     4842
# nl     4571
# tr     2266
# it     2249
# ar     1777
# pt     1572
# gu     1511
# in     1445
# pl     1412
# zh     882
# hi     778
# sv     709
# ca     536
# et     528
# el     522
# ko     423
# tl     415
# ht     383
# ru     359
# fi     345
# da     320
# cs     296
# ta     239
# sr     202
# ro     197
# iw     196
# sl     162
# no     136
# th     128
# cy     111
# te     105
# fa     89
# lt     88
# lv     64
# hu     61
# is     40
# eu     34
# ur     25
# bg     17
# uk     16
# ne     10
# mr     9
# vi     9
# kn     7
# am     6
# ml     6
# bn     5
# dv     4
# or     3
# pa     2
# ps     1
# Name: lang, dtype: int64

# %%
# 'und' means language was undetected
# seems like these tweets don't have much text

vax_full[vax_full['lang'] == 'und']
# Out:
#         coordinates                      created_at  \
# 17       NaN         Sun Nov 01 07:09:57 +0000 2020
# 20       NaN         Sun Nov 01 07:15:10 +0000 2020
# 40       NaN         Sun Nov 01 07:35:59 +0000 2020
# 50       NaN         Sun Nov 01 07:42:47 +0000 2020
# 72       NaN         Sun Nov 01 08:18:55 +0000 2020
# ...      ...                                    ...
# 1099727  NaN         Wed Apr 21 06:27:00 +0000 2021
# 1099790  NaN         Wed Apr 21 06:39:45 +0000 2021
# 1099799  NaN         Wed Apr 21 06:43:15 +0000 2021
# 1099813  NaN         Wed Apr 21 06:39:54 +0000 2021
# 1099882  NaN         Wed Apr 21 06:49:25 +0000 2021
#
#                                                                                              hashtags  \
# 17       Nomask MaskOFF NoVaccine
# 20       NaN
# 40       NaN
# 50       EndSARS EndMilitaryBrutality EndPoliceBrutalityinNigera EndBadGoveranceInNigeria
# 72       NaN
# ...      ...
# 1099727  Mask Masks FaceMask FaceMasks FaceDiaper FaceDiapers MaskMandate MaskMandates MedicalFreedom
# 1099790  NaN
# 1099799  NaN
# 1099813  NaN
# 1099882  NaN
#
#                                                                           media  \
# 17       https://twitter.com/Schille18336614/status/1322798014566703104/photo/1
# 20       NaN
# 40       NaN
# 50       NaN
# 72       NaN
# ...      ...
# 1099727  NaN
# 1099790  NaN
# 1099799  NaN
# 1099813  NaN
# 1099882  NaN
#
#                                                                                                                                  urls  \
# 17       NaN
# 20       https://twitter.com/sunnynwaobi1/status/1322434241829982208
# 40       https://twitter.com/conspiracyb0t/status/1322791741854937089
# 50       NaN
# 72       https://twitter.com/ForcedAdoption1/status/1322810228988026880
# ...                                                                 ...
# 1099727  https://www.instagram.com/p/CN6vxB0AjXd/?igshid=lqy30ohrdn9b
# 1099790  https://twitter.com/kurtwearshats/status/1384564021202882565
# 1099799  https://montanadailygazette.com/2021/04/16/unvaccinated-women-report-miscarriages-after-interactions-with-vaccinated-people/
# 1099813  NaN
# 1099882  NaN
#
#          favorite_count                   id in_reply_to_screen_name  \
# 17       0               1322798014566703104  FOX29philly
# 20       0               1322799327044161537  ARISEtv
# 40       0               1322804564559499265  ashwani_mahajan
# 50       0               1322806277760864256  NaN
# 72       0               1322815370332266499  hakki501
# ...     ..                               ...       ...
# 1099727  0               1384755531299045376  NaN
# 1099790  1               1384758740100861955  NaN
# 1099799  0               1384759617528340483  NaN
# 1099813  0               1384758774301224962  NaN
# 1099882  0               1384761169244835840  NaN
#
#          in_reply_to_status_id  in_reply_to_user_id lang       place  \
# 17       1.322796e+18           1.478771e+07         und  NaN
# 20      NaN                     1.087779e+09         und  NaN
# 40      NaN                     2.156856e+08         und  NaN
# 50      NaN                    NaN                   und  NaN
# 72       1.322810e+18           4.013243e+08         und  NaN
# ...               ...                    ...         ...  ...
# 1099727 NaN                    NaN                   und  NaN
# 1099790 NaN                    NaN                   und  Irvine, CA
# 1099799 NaN                    NaN                   und  NaN
# 1099813 NaN                    NaN                   und  NaN
# 1099882 NaN                    NaN                   und  NaN
#
#         possibly_sensitive             quote_id  retweet_count  \
# 17       False              <NA>                 0
# 20       False              1322434241829982208  0
# 40       False              1322791741854937088  0
# 50       NaN                1322434241829982208  2
# 72       False              1322810228988026880  0
# ...        ...                              ... ..
# 1099727  False              <NA>                 0
# 1099790  False              1384564021202882560  0
# 1099799  False              <NA>                 0
# 1099813  NaN                1384564021202882560  49
# 1099882  NaN                1384564021202882560  49
#
#                   retweet_id retweet_screen_name  \
# 17       <NA>                 NaN
# 20       <NA>                 NaN
# 40       <NA>                 NaN
# 50       1322611480898973696  Bubblybee_Chi
# 72       <NA>                 NaN
# ...       ...                 ...
# 1099727  <NA>                 NaN
# 1099790  <NA>                 NaN
# 1099799  <NA>                 NaN
# 1099813  1384738849180450816  KingJosiah54
# 1099882  1384738849180450816  KingJosiah54
#
#                                                                                        source  \
# 17       <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# 20       <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 40       <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 50       <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 72       <a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>
# ...                                                                          ...
# 1099727  <a href="http://instagram.com" rel="nofollow">Instagram</a>
# 1099790  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1099799  <a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>
# 1099813  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1099882  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                                   text  \
# 17       @FOX29philly #Nomask #MaskOFF #NoVaccine https://t.co/55ZzqhJFo8
# 20       @ARISEtv https://t.co/n5y4J0oAlU
# 40       @ashwani_mahajan https://t.co/camEcwIpvo
# 50       #EndSARS\n#EndMilitaryBrutality \n#EndPoliceBrutalityinNigera \n#EndBadGoveranceInNigeria https://t.co/ykBOkVRRLc
# 72       https://t.co/H9H559xnhp
# ...                          ...
# 1099727  #Mask #Masks #FaceMask #FaceMasks #FaceDiaper #FaceDiapers #MaskMandate #MaskMandates #MedicalFreedom https://t.co/naFkIu1W6F
# 1099790  😂😂😂😂😂 https://t.co/dlBkxWQyZ2
# 1099799  https://t.co/rZmyXHcIZi
# 1099813  😂😂😂😂😂😂 https://t.co/EuGgqxKscL
# 1099882  😂😂😂😂😂😂 https://t.co/EuGgqxKscL
#
#                                                               tweet_url  \
# 17       https://twitter.com/Schille18336614/status/1322798014566703104
# 20       https://twitter.com/kenzykayoficial/status/1322799327044161537
# 40       https://twitter.com/devsr84/status/1322804564559499265
# 50       https://twitter.com/IkeLObidike/status/1322806277760864256
# 72       https://twitter.com/hakki501/status/1322815370332266499
# ...                                                          ...
# 1099727  https://twitter.com/JMichW87/status/1384755531299045376
# 1099790  https://twitter.com/angel0bugatti/status/1384758740100861955
# 1099799  https://twitter.com/AlainBeydoun/status/1384759617528340483
# 1099813  https://twitter.com/SpcMtn/status/1384758774301224962
# 1099882  https://twitter.com/bmalcolm21/status/1384761169244835840
#
#                         user_created_at              user_id  \
# 17       Mon Sep 14 02:01:02 +0000 2020  1305325569815515136
# 20       Mon Jan 03 16:02:06 +0000 2011  233576830
# 40       Fri Apr 23 07:18:45 +0000 2010  136185881
# 50       Tue Feb 22 10:38:12 +0000 2011  255949363
# 72       Sun Oct 30 11:27:55 +0000 2011  401324299
# ...                                 ...        ...
# 1099727  Tue Jun 16 16:17:56 +0000 2020  1272926339696398336
# 1099790  Sat May 12 19:28:45 +0000 2012  578330624
# 1099799  Thu Mar 08 08:52:28 +0000 2012  518323576
# 1099813  Fri Apr 10 03:46:16 +0000 2009  30153135
# 1099882  Mon Jan 16 16:24:30 +0000 2012  465671698
#
#          user_default_profile_image  \
# 17       False
# 20       False
# 40       False
# 50       False
# 72       False
# ...        ...
# 1099727  True
# 1099790  False
# 1099799  False
# 1099813  False
# 1099882  False
#
#                                                                                                                                                 user_description  \
# 17       „Sei ein Freund der Schwachen und liebe die Gerechtigkeit.“\n\n#Testboykott  #NeinzumImpfzwang\n#RücktrittBundesregierung ⚔ #impfapartheid #Ungehorsam
# 20       SEO Specialist / music lover / Digital Marketer / Red Devil
# 40       Working on Ergonomics, IITian, Blogger, Tech Enthusiast, Wannabe Entrepreneur, Student of History & Geo-Politics ...
# 50       Chemical Engineer (PhD), Author (Shifting Sands), Pro-Life, Non-absent Dad, Football Analyst, Arsenal fan, Scrabbler, Pragmatists, Humanist, Christian.
# 72       Nothing to boast of except the cross of Jesus Christ.\nSaved by His grace through faith. (Ephesians 2: 8,9)
# ...                                                                                                              ...
# 1099727  NaN
# 1099790  Middle-aged black man with sass. Big butt. Bigger heart. | Debater.
# 1099799  NaN
# 1099813  As long as I’m in Polo smiling, they think they got me But they would try to crack me if they ever see a black me.
# 1099882  Marketing🧑🏾‍💻|College Student📚|Military Veteran🇺🇸 |Marketing💰: $45k+ in Revenue under 90 Days| I help people find a side-hustle that works for them 🚨|
#
#          user_favourites_count  user_followers_count  user_friends_count  \
# 17       7499                   231                   389
# 20       124                    339                   898
# 40       6391                   704                   4980
# 50       8468                   419                   329
# 72       26734                  905                   1377
# ...        ...                  ...                    ...
# 1099727  383                    6                     222
# 1099790  36628                  268                   930
# 1099799  67                     13                    28
# 1099813  34189                  294                   3370
# 1099882  17218                  1029                  636
#
#          user_listed_count                   user_location  \
# 17       0                  Linköping
# 20       3                  Nigeria
# 40       15                 Mumbai
# 50       8                  Johannesburg
# 72       50                 Temporary residence: Earth. Pe
# ...      ..                                            ...
# 1099727  0                  Hollywood, FL
# 1099790  4                  Irvine, CA
# 1099799  0                  cairns
# 1099813  8                  somewhr in outerspace
# 1099882  3                  Atlanta, GA
#
#                     user_name user_screen_name  user_statuses_count  \
# 17       Schiller ✝⚔⛪ 🇩🇪🇦🇹     Schille18336614  7577
# 20       KenzyKay ¦ 20-10-20💔  kenzykayoficial  5179
# 40       Devindra Singh        devsr84          55837
# 50       Dr. Ike Obidike       IkeLObidike      12310
# 72       J.                    hakki501         29961
# ...      ..                         ...           ...
# 1099727  Jamie White           JMichW87         1639
# 1099790  Angelo                angel0bugatti    46080
# 1099799  byblos cafe           AlainBeydoun     138
# 1099813  Petty Mahomes         SpcMtn           35105
# 1099882  Bmalcolm21            bmalcolm21       56682
#
#          user_time_zone                        user_urls  user_verified
# 17      NaN              https://report24.news/           False
# 20      NaN              NaN                              False
# 40      NaN              https://www.twitter.com/devsr84  False
# 50      NaN              NaN                              False
# 72      NaN              NaN                              False
# ...      ..              ...                                ...
# 1099727 NaN              NaN                              False
# 1099790 NaN              https://vsco.co/angelo-bugatti   False
# 1099799 NaN              http://bybloscafe.com.au         False
# 1099813 NaN              NaN                              False
# 1099882 NaN              https://linktr.ee/Bmalcolm21     False
#
# [53757 rows x 35 columns]

# %% [markdown]
# ### Hashtags

# %%
# most commonly used hashtags (although some of these may appear common because of retweets)
# some are clearly anti-vaccine, while others are neutral

vax_full['hashtags'].value_counts().head(30)
# Out:
# NoVaccineForMe                              4368
# COVID19                                     4266
# mybodymychoice                              3514
# FireFauci WeWillNotComply                   3118
# MyBodyMyChoice                              3018
# InformedConsent                             2555
# VaccineforSouthAfrica                       2197
# BillGatesBioTerrorist                       2154
# ArrestBillGates                             2027
# NoVaccine                                   1893
# IDoNotConsent                               1284
# COVID                                       850
# depopulation                                837
# vaccine                                     700
# LongCovid                                   690
# BREAKING COVID19                            683
# GreatReset                                  675
# vaccines                                    637
# VAXXED                                      537
# arrestbillgates                             530
# ScottyDoesNothing                           505
# vaxxed                                      490
# Israel                                      478
# Ontario                                     465
# BillGates                                   455
# ExposeBillGates                             438
# Depopulation                                434
# unmasked unmuzzled unvaccinated unafraid    429
# DemVoice1 ONEV1 FreshScience wtpBLUE        425
# WeWillNotComply                             425
# Name: hashtags, dtype: int64

# %% [markdown]
# ## Clean dataset

# %%
# full dataset contains 45K unique tweets 

vax_full['text'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6051b1d8e514> in <module>
#       1 # full dataset contains 45K unique tweets
#       2
# ----> 3 vax_full['text'].nunique()
#
# NameError: name 'vax_full' is not defined

# %%
# dropping duplicate tweets

vax_tweets = vax_full.drop_duplicates(subset='text', keep='first')
vax_tweets.shape
# Out:
# (457573, 35)

# %%
# keeping only tweets that are in English

vax_tweets = vax_tweets[vax_tweets['lang'] == 'en']
vax_tweets.shape
# Out:
# (396605, 35)

# %%
vax_tweets.to_csv('vax_tweets.csv', index=False)
